# %% [markdown]
# # Дипломный проект: ML для обработки обращений

# %% [markdown]
# Представьте, что вы работаете в компании с техподдержкой. Сейчас операторы вручную обрабатывает новые обращения. Вам необходимо предложить и проверить MVP, который помогает ускорить обработку.

# %%
import pandas as pd
df = pd.read_csv('customer_support_tickets.csv')

# %%
df.head()
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 1) Выберите бизнес-цель
#
# Выберите одну цель (или предложите свою):
#
# - Маршрутизация (Routing): автоматически определять категорию/очередь обращения
# - Приоритизация: определять срочные/сложные обращения, чтобы давать их опытным специалистам.
# - Подсказка “что делать дальше”: классифицировать тип сообщения (например: уточнение, предложение решения, подтверждение, “не помогло”) — чтобы помогать оператору вести диалог.

# %%
# your goal and KPI
# ...
#
#

# %% [markdown]
# ---

# %% [markdown]
# ### 2) Для выбранной бизнес-цели cформулируйте ML-задачу и метрики

# %%
# your ML task
# ...
#
#

# %% [markdown]
# ---

# %% [markdown]
# ### 3) Обучите MVP и замерьте метрики

# %%
def process_dataset():
  # to be added
  pass

def get_target():
  # to be added
  pass

def fit_model():
  # to be added
  pass

def check_metrics():
  # to be added
  pass

# %% [markdown]
# ---

# %% [markdown]
# ### 4) Оцените, когда решение “работает хорошо” (и когда нет)
#
#
# Нужно учесть полученные метрики, связь с KPI. Возможен подход с оценкой снижения затарат на саппорт (измерять можно в человеко-часах или деньгах).
